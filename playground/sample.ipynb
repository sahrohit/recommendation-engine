# %%
import matplotlib.pyplot as plt

# %%
data = [
    1.0726046873826458,
    1.0726493739667242,
    1.072758832653683,
    1.0728491944183447,
    1.0730330260516174,
    1.0753229281412784,
    1.075480663561971,
    1.0761851474385373,
    1.0763419061709816,
    1.0763580984894978,
    1.0763602465199797,
    1.0704672397423978,
]

labels = [
    "svd",
    "knn_bsl_u",
    "knn_bsl_m",
    "svdpp",
    "bsl_algo",
    "xgb_knn_bsl_mu",
    "xgb_all_models",
    "first_algo",
    "xgb_bsl",
    "xgb_final",
    "xgb_knn_bsl",
    "desc_analysis"
]
plt.figure(figsize=(16, 10))

plt.plot(labels, data, marker='o', linestyle='--')
plt.ylim(1.060, 1.079)
plt.tick_params(axis='x', labelrotation=90)

# Set the plot title and labels
plt.title('')
plt.xlabel('Models')
plt.ylabel('RMSE')

# Display the plot
plt.show()
